# %%
import pandas as pd

# Replace 'your_file.csv' with the actual filename of your CSV file.
df = pd.read_csv('craigslist_vehicles.csv')

# Display the first few rows of the DataFrame to check if the data has been loaded correctly.
df.head()
# Out:
#    Unnamed: 0          id                                                url  \
# 0      362773  7307679724  https://abilene.craigslist.org/ctd/d/abilene-2...
# 1      362712  7311833696  https://abilene.craigslist.org/ctd/d/abilene-2...
# 2      362722  7311441996  https://abilene.craigslist.org/ctd/d/abilene-2...
# 3      362771  7307680715  https://abilene.craigslist.org/ctd/d/abilene-2...
# 4      362710  7311834578  https://abilene.craigslist.org/ctd/d/abilene-2...
#
#     region                      region_url  price    year manufacturer  \
# 0  abilene  https://abilene.craigslist.org   4500  2002.0          bmw
# 1  abilene  https://abilene.craigslist.org   4500  2002.0          bmw
# 2  abilene  https://abilene.craigslist.org   4900  2006.0       toyota
# 3  abilene  https://abilene.craigslist.org   6500  2008.0         ford
# 4  abilene  https://abilene.craigslist.org   6500  2008.0         ford
#
#         model  condition  ...   type paint_color  \
# ...

# %%
# Identify numerical and categorical columns
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
categorical_columns = df.select_dtypes(include=['object']).columns

# Calculate the median for numerical columns and the mode for categorical columns
median_values = df[numerical_columns].median()
mode_values = df[categorical_columns].mode().iloc[0]

# Fill in missing values with medians and modes
df[numerical_columns] = df[numerical_columns].fillna(median_values)
df[categorical_columns] = df[categorical_columns].fillna(mode_values)

# Check for any remaining missing values
missing_values = df.isnull().sum()

# %%
df.head()
# Out:
#    Unnamed: 0          id                                                url  \
# 0      362773  7307679724  https://abilene.craigslist.org/ctd/d/abilene-2...
# 1      362712  7311833696  https://abilene.craigslist.org/ctd/d/abilene-2...
# 2      362722  7311441996  https://abilene.craigslist.org/ctd/d/abilene-2...
# 3      362771  7307680715  https://abilene.craigslist.org/ctd/d/abilene-2...
# 4      362710  7311834578  https://abilene.craigslist.org/ctd/d/abilene-2...
#
#     region                      region_url  price    year manufacturer  \
# 0  abilene  https://abilene.craigslist.org   4500  2002.0          bmw
# 1  abilene  https://abilene.craigslist.org   4500  2002.0          bmw
# 2  abilene  https://abilene.craigslist.org   4900  2006.0       toyota
# 3  abilene  https://abilene.craigslist.org   6500  2008.0         ford
# 4  abilene  https://abilene.craigslist.org   6500  2008.0         ford
#
#         model  condition  ...   type paint_color  \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# id                int64
# url              object
# region           object
# region_url       object
# price             int64
# year            float64
# manufacturer     object
# model            object
# condition        object
# cylinders        object
# fuel             object
# odometer        float64
# title_status     object
# transmission     object
# VIN              object
# drive            object
# size             object
# type             object
# paint_color      object
# image_url        object
# description      object
# county          float64
# state            object
# lat             float64
# long            float64
# posting_date     object
# removal_date     object
# dtype: object

# %%
df['posting_date'] = pd.to_datetime(df['posting_date'], format='%Y-%m-%d 00:00:00+00:00', errors='coerce')

# The 'format' parameter is used to specify the date format in your 'date_column'.
# If you know the format, replace '%Y-%m-%d' with your actual date format.

# The 'errors' parameter is set to 'coerce', which will handle any parsing errors by converting them to NaT (Not-a-Time) values.

# %%
df.head()
# Out:
#                posting_date
# 0 2021-04-16 00:00:00+00:00
# 1 2021-04-24 00:00:00+00:00
# 2 2021-04-23 00:00:00+00:00
